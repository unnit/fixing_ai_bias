# %%
import sys
# !{sys.executable} -m pip install facenet-pytorch
# Out:
# Collecting facenet-pytorch
#   Downloading facenet_pytorch-2.6.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.24.0 in /Users/dheerajt/.pyenv/versions/my_env/lib/python3.11/site-packages (from facenet-pytorch) (1.26.4)
# Collecting Pillow<10.3.0,>=10.2.0 (from facenet-pytorch)
#   Downloading pillow-10.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.7 kB)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /Users/dheerajt/.pyenv/versions/my_env/lib/python3.11/site-packages (from facenet-pytorch) (2.32.3)
# Collecting torch<2.3.0,>=2.2.0 (from facenet-pytorch)
#   Downloading torch-2.2.2-cp311-none-macosx_11_0_arm64.whl.metadata (25 kB)
# Collecting torchvision<0.18.0,>=0.17.0 (from facenet-pytorch)
#   Downloading torchvision-0.17.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.0.0 in /Users/dheerajt/.pyenv/versions/my_env/lib/python3.11/site-packages (from facenet-pytorch) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dheerajt/.pyenv/versions/my_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dheerajt/.pyenv/versions/my_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dheerajt/.pyenv/versions/my_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dheerajt/.pyenv/versions/my_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (2025.1.31)
# Requirement already satisfied: filelock in /Users/dheerajt/.pyenv/versions/my_env/lib/python3.11/site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/dheerajt/.pyenv/versions/my_env/lib/python3.11/site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (4.12.2)
# Requirement already satisfied: sympy in /Users/dheerajt/.pyenv/versions/my_env/lib/python3.11/site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (1.13.1)
# Requirement already satisfied: networkx in /Users/dheerajt/.pyenv/versions/my_env/lib/python3.11/site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/dheerajt/.pyenv/versions/my_env/lib/python3.11/site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (3.1.5)
# Requirement already satisfied: fsspec in /Users/dheerajt/.pyenv/versions/my_env/lib/python3.11/site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (2024.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dheerajt/.pyenv/versions/my_env/lib/python3.11/site-packages (from jinja2->torch<2.3.0,>=2.2.0->facenet-pytorch) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/dheerajt/.pyenv/versions/my_env/lib/python3.11/site-packages (from sympy->torch<2.3.0,>=2.2.0->facenet-pytorch) (1.3.0)
# Downloading facenet_pytorch-2.6.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 4.2 MB/s eta 0:00:0000:0100:01
# Downloading pillow-10.2.0-cp311-cp311-macosx_11_0_arm64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 4.2 MB/s eta 0:00:00a 0:00:01
# Downloading torch-2.2.2-cp311-none-macosx_11_0_arm64.whl (59.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 MB 21.0 MB/s eta 0:00:00a 0:00:01
# Downloading torchvision-0.17.2-cp311-cp311-macosx_11_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 36.2 MB/s eta 0:00:00
# Installing collected packages: Pillow, torch, torchvision, facenet-pytorch
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1
#     Uninstalling torch-2.5.1:
#       Successfully uninstalled torch-2.5.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1
#     Uninstalling torchvision-0.20.1:
#       Successfully uninstalled torchvision-0.20.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastbook 0.0.29 requires ipywidgets<8, but you have ipywidgets 8.1.2 which is incompatible.
# syft 0.9.5 requires numpy<=1.24.4,>=1.23.5; python_version < "3.12", but you have numpy 1.26.4 which is incompatible.
# syft 0.9.5 requires packaging>=23.0, but you have packaging 22.0 which is incompatible.
# Successfully installed Pillow-10.2.0 facenet-pytorch-2.6.0 torch-2.2.2 torchvision-0.17.2

# %%
from facenet_pytorch import MTCNN, InceptionResnetV1
import torch
import pandas as pd
import numpy as np
from PIL import Image

# %%
import os

# Specify the folder path
folder_path = 'images'

# Get all file names in the folder
file_names = os.listdir(folder_path)

# Optionally, filter to only get files (exclude subdirectories)
file_names = [file for file in file_names if os.path.isfile(os.path.join(folder_path, file))]

# Print the list of file names
print(file_names)
# Out:
# ['Aaron_Eckhart_0001.jpg', 'Brad_Gushue_0001.jpg', 'Clare_Latimer_0001.jpg', 'Anthony_Hopkins_0002.jpg', 'Aaron_Patterson_0001.jpg', 'David_Myers_0001.jpg', 'Aaron_Guiel_0001.jpg', 'Aaron_Pena_0001.jpg', 'Aaron_Peirsol_0001.jpg', 'Clint_Lamebear_0001.jpg', 'Brenda_Wilson_0001.jpg', 'Barbara_Walters_0003.jpg', 'Ashton_Kutcher_0001.jpg', 'Billy_Bob_Thornton_0001.jpg', 'Arnold_Schwarzenegger_0003.jpg']

# %%
# Initialize MTCNN for face detection and InceptionResnetV1 for feature extraction
mtcnn = MTCNN(image_size=160, margin=0)  # Adjust image_size and margin as needed
resnet = InceptionResnetV1(pretrained='vggface2').eval()

# %% [markdown]
# ## Extract Feature Vectors from images
# - MTCNN is used to detect faces in the image and provide bounding boxes.
# - InceptionResnetV1, pre-trained on a large dataset of faces (VGGFace2), is used to extract feature vectors representing the unique characteristics of each detected face.
# - These feature vectors can then be used for facial recognition tasks like comparing faces, identifying individuals, and more.

# %%
df = pd.DataFrame(columns=['File Name', 'Feature Vector'])
folder_path = 'images'
for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    if os.path.isfile(file_path):
        try:
            # Load the image
            img = Image.open(file_path)
            
            # Detect faces in the image
            boxes, _ = mtcnn.detect(img, landmarks=False)
            
            # If no faces are detected, skip this image
            if boxes is None or len(boxes) == 0:
                print(f"No faces detected in {file_name}")
                continue  # Skip to the next image
            
            for box in boxes:
                # Crop the face from the image
                face = img.crop(box.tolist())
                
                # Preprocess the face for InceptionResnetV1
                face_tensor = torch.stack([mtcnn(face)])
                
                # Extract the feature vector
                feature_vector = resnet(face_tensor).detach().numpy()

                # Create a temporary DataFrame to hold the results for the current image
                temp_df = pd.DataFrame({
                    'File Name': [file_name],
                    'Feature Vector': feature_vector.tolist()
                })

                
                # Add the result to the DataFrame
                df = pd.concat([df, temp_df], ignore_index=True)
        except Exception as e:
            print(f"Error processing {file_name}: {e}")

# %%
df
# Out:
#                          File Name  \
# 0           Aaron_Eckhart_0001.jpg
# 1             Brad_Gushue_0001.jpg
# 2           Clare_Latimer_0001.jpg
# 3         Anthony_Hopkins_0002.jpg
# 4         Aaron_Patterson_0001.jpg
# 5             David_Myers_0001.jpg
# 6             Aaron_Guiel_0001.jpg
# 7              Aaron_Pena_0001.jpg
# 8           Aaron_Peirsol_0001.jpg
# 9          Clint_Lamebear_0001.jpg
# 10          Brenda_Wilson_0001.jpg
# 11        Barbara_Walters_0003.jpg
# 12         Ashton_Kutcher_0001.jpg
# 13     Billy_Bob_Thornton_0001.jpg
# 14  Arnold_Schwarzenegger_0003.jpg
#
#                                        Feature Vector
# 0   [-0.002311188727617264, -0.10527217388153076, ...
# 1   [-0.035913366824388504, 0.04265087470412254, -...
# 2   [0.030108239501714706, 0.020737478509545326, 0...
# 3   [-0.015597607009112835, 0.03488968685269356, -...
# 4   [0.03616906329989433, 0.042094238102436066, 0....
# 5   [0.05999491736292839, -0.06570962071418762, -0...
# 6   [0.045506350696086884, 0.000562878733035177, 0...
# 7   [0.0493774339556694, -0.008196741342544556, 0....
# 8   [0.0042321570217609406, 0.002834965707734227, ...
# 9   [0.023235436528921127, 0.09349582344293594, 0....
# 10  [0.020045142620801926, 0.05714983865618706, 0....
# 11  [0.011150584556162357, 0.014378128573298454, 0...
# 12  [0.014160815626382828, -0.05431190878152847, -...
# 13  [0.009770314209163189, 0.006564945448189974, 0...
# 14  [0.01033375971019268, -0.09689470380544662, 0....

# %% [markdown]
# #### We got all 15 images converted to feature vectors

# %% [markdown]
# ## Differential Privacy
# - The Laplace mechanism adds random noise drawn from a Laplace distribution to the feature vector.
# - The amount of noise is controlled by the privacy budget (epsilon) and the sensitivity of the data.
# - A smaller epsilon value results in more noise and stronger privacy protection.
#
# We need to go through the Dataframe and apply differential privacy on feature vectors which is the privacy preserving technique.
#
# The randomise function of the Laplace mechanism is used to add noise to the feature vector, making it differentially private.

# %%
from diffprivlib.mechanisms import Laplace

# %% [markdown]
# #### Initialize the Laplace mechanism for differential privacy

# %%
epsilon = 1.0  # Privacy budget (epsilon)
mechanism = Laplace(epsilon=epsilon, sensitivity=1)

# %%
df['Private Feature Vector'] = df['Feature Vector'].apply(
    lambda feature_vector: [mechanism.randomise(val) for val in np.array(feature_vector)]
)

# %%
df
# Out:
#                          File Name  \
# 0           Aaron_Eckhart_0001.jpg
# 1             Brad_Gushue_0001.jpg
# 2           Clare_Latimer_0001.jpg
# 3         Anthony_Hopkins_0002.jpg
# 4         Aaron_Patterson_0001.jpg
# 5             David_Myers_0001.jpg
# 6             Aaron_Guiel_0001.jpg
# 7              Aaron_Pena_0001.jpg
# 8           Aaron_Peirsol_0001.jpg
# 9          Clint_Lamebear_0001.jpg
# 10          Brenda_Wilson_0001.jpg
# 11        Barbara_Walters_0003.jpg
# 12         Ashton_Kutcher_0001.jpg
# 13     Billy_Bob_Thornton_0001.jpg
# 14  Arnold_Schwarzenegger_0003.jpg
#
#                                        Feature Vector  \
# 0   [-0.002311188727617264, -0.10527217388153076, ...
# 1   [-0.035913366824388504, 0.04265087470412254, -...
# 2   [0.030108239501714706, 0.020737478509545326, 0...
# 3   [-0.015597607009112835, 0.03488968685269356, -...
# 4   [0.03616906329989433, 0.042094238102436066, 0....
# 5   [0.05999491736292839, -0.06570962071418762, -0...
# 6   [0.045506350696086884, 0.000562878733035177, 0...
# 7   [0.0493774339556694, -0.008196741342544556, 0....
# 8   [0.0042321570217609406, 0.002834965707734227, ...
# 9   [0.023235436528921127, 0.09349582344293594, 0....
# 10  [0.020045142620801926, 0.05714983865618706, 0....
# 11  [0.011150584556162357, 0.014378128573298454, 0...
# 12  [0.014160815626382828, -0.05431190878152847, -...
# 13  [0.009770314209163189, 0.006564945448189974, 0...
# 14  [0.01033375971019268, -0.09689470380544662, 0....
#
#                                Private Feature Vector
# 0   [-0.21113548655704514, 1.3718263810558629, -0....
# 1   [-0.8876701063542562, 0.1100928728368665, 2.88...
# 2   [0.6208223562587766, -0.10680521329388501, -0....
# 3   [-0.3088659910182231, -0.5512908165309908, -0....
# 4   [-0.60065428368628, 2.528669975895604, 0.59104...
# 5   [0.24649726641270064, 3.4461946622857638, 1.48...
# 6   [1.0570975117926555, 2.750035000864362, 2.1146...
# 7   [-0.37401100886747274, 0.0695385084096332, 0.1...
# 8   [-0.1597989283252332, 2.164862852860284, 0.116...
# 9   [0.4722784242925023, -0.16232059962792966, 1.6...
# 10  [1.1329890604646895, -1.8074498198979603, -2.0...
# 11  [0.69558941973227, 0.27819710456299607, 1.4200...
# 12  [3.8202559137707857, -3.127919603500567, 0.253...
# 13  [-0.8723131359340107, 0.9140606542047203, 1.23...
# 14  [-0.22034123235896408, -0.47033483707948337, 0...

# %% [markdown]
# ### As we can see the new called Private Feature Vector got created which has applied the differential privacy on Fetaure Vector
